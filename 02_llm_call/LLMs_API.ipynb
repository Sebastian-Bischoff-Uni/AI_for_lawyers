# %% [markdown]
# ### Einfache Anfrage an Gemini-Modell

# %% [markdown]
# 1. OpenAI-API-Key erstellen auf der [API-Plattform](https://ai.google.dev/gemini-api/docs/api-key)
# 2. Beispielcode findet sich auf der [API-Dokumentation unter "Overview"](https://ai.google.dev/gemini-api/docs)
# 3. Eine Übersicht über verfügbare Modelle und die korrespondierenden Kosten findet sich [hier](https://ai.google.dev/gemini-api/docs/models)
# 4. Die offizielle Kurzanleitung inden Sie [hier](https://ai.google.dev/gemini-api/docs/quickstart?hl=de)

# %%
from google import genai

client = genai.Client()
prompt = "schreib mir eine kurze Zusammenfassung über die Vor- und Nachteile von OOP in Python"

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=prompt,
)

print(response.text)
# Out:
# ...
# Objektorientierte Programmierung (OOP) ist in Python tief verwurzelt – tatsächlich ist in Python fast alles ein Objekt. Hier ist eine kompakte Zusammenfassung der Vor- und Nachteile:
#
# ### Vorteile von OOP in Python
#
# 1.  **Wiederverwendbarkeit:** Durch **Vererbung** können bestehende Klassen erweitert werden, ohne den Code neu schreiben zu müssen. Das spart Zeit und reduziert Redundanz (DRY-Prinzip: *Don't Repeat Yourself*).
# 2.  **Struktur und Übersichtlichkeit:** Komplexe Projekte werden in kleinere, logische Einheiten (Objekte) unterteilt. Dies macht den Code modularer und leichter verständlich.
# 3.  **Wartbarkeit:** Da Daten und Funktionen in Klassen gekapselt sind, können Änderungen an einer Stelle vorgenommen werden, ohne das gesamte Programm zu gefährden.
# 4.  **Datenkapselung:** Interna einer Klasse können verborgen werden (Information Hiding). Dies schützt die Daten vor unbeabsichtigten Manipulationen von außen.
# ...

# %% [markdown]
# ### Einfache Anfrage an OpenAI-Modell

# %% [markdown]
# 1. OpenAI-API-Key erstellen auf der [API-Plattform](https://platform.openai.com/home)
# 2. Beispielcode findet sich auf der [OpenAI Developers Plattform](https://developers.openai.com/api/docs/quickstart?language=python)
# 3. Eine Übersicht über verfügbare Modelle und die korrespondierenden Kosten findet sich [hier](https://developers.openai.com/api/docs/pricing)

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.4",
    input="kann ich durch Kaufvertrag Eigentum erwerben im deutschen Recht?"
)

print(response.output_text)
# Out:
# Ja — **durch einen Kaufvertrag allein noch nicht**, aber **im Zusammenspiel mit weiteren Voraussetzungen** kann man im deutschen Recht Eigentum erwerben.
#
# ## Kurz gesagt
# Im deutschen Recht gilt das **Trennungs- und Abstraktionsprinzip**:
#
# - **Kaufvertrag** (§ 433 BGB) = verpflichtet nur dazu,
#   - der Verkäufer muss die Sache übereignen,
#   - der Käufer muss den Kaufpreis zahlen.
# - **Eigentumserwerb** passiert erst durch ein **gesondertes Verfügungsgeschäft**.
#
# ## Bei beweglichen Sachen
# Zum Eigentumserwerb braucht man grundsätzlich:
#
# 1. **Einigung über den Eigentumsübergang** (§ 929 S. 1 BGB)
# 2. **Übergabe** der Sache
# 3. **Berechtigung** des Veräußerers
#
# Also:
# - Der **Kaufvertrag** allein macht dich noch nicht zum Eigentümer.
# - Erst **Kaufvertrag + Übereignung** führen in der Regel zum Eigentum.
#
# ### Beispiel
# Du kaufst ein Fahrrad.
# - Mit dem Kaufvertrag hast du einen **Anspruch** auf Übergabe und Übereignung.
# ...
